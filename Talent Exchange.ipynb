# %%
import pandas as pd
from graphdatascience import GraphDataScience
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

gds = GraphDataScience('bolt://localhost:7687', auth = ('neo4j', 'wxp614503'))

# %%
# Clear last graph - All data and schema attributes
gds.run_cypher('MATCH(n) DETACH DELETE n')
gds.run_cypher('CALL apoc.schema.assert({},{})')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8c/vnmy4vpj1q32d2g_xhsq6z5w0000gn/T/ipykernel_64280/300373079.py in <module>
#       1 # Clear last graph - All data and schema attributes
# ----> 2 gds.run_cypher('MATCH(n) DETACH DELETE n')
#       3 gds.run_cypher('CALL apoc.schema.assert({},{})')
#
# NameError: name 'gds' is not defined

# %%
gds.run_cypher('CREATE CONSTRAINT job_unique IF NOT EXISTS ON (n:Job) ASSERT n.Id IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT freelancer_unique IF NOT EXISTS ON (n:Freelancer) ASSERT n.Id IS UNIQUE')

gds.run_cypher('CREATE CONSTRAINT area_unique IF NOT EXISTS ON (n:Area) ASSERT n.Name IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT skill_unique IF NOT EXISTS ON (n:Skill) ASSERT n.Name IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT certification_unique IF NOT EXISTS ON (n:Certification) ASSERT n.Name IS UNIQUE')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
folder = 'C:/Users/xwang338/Desktop/Project/2022 - US - Talent Exchange NLP/Data/'
file = 'freelancers.xlsx'

df = pd.read_excel(folder + file, sheet_name = 'certification')

# %%
import re

df = df.dropna(subset = ['CertificationValue'])
df['CertificationValue'] = df['CertificationValue'].str.replace(re.compile('[^a-zA-Z0-9 \n\.\+\#\(\)]'), '')

# %%
df.to_csv(folder + 'freelancers_certification.csv', index = False)

# %% [markdown]
# # Job

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///jobs_summary.csv' AS line
    MERGE (n:Job {Id: line.jobid}) SET n.Title = line.jobtitle
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///jobs_focus_area.csv' AS line
    MATCH (n:Job) WHERE n.Id = line.jobid
    MERGE (m:Area {Name: line.FocusAreaDescription})
    MERGE (n)-[r:FOCUS]->(m)
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///jobs_skill.csv' AS line
    MATCH (n:Job) WHERE n.Id = line.jobid
    MERGE (m:Skill {Name: line.skillname})
    MERGE (n)-[r:REQUIRE]->(m)
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///jobs_certification.csv' AS line
    MATCH (n:Job) WHERE n.Id = line.jobid
    MERGE (m:Certification {Name: line.CertificationValue})
    MERGE (n)-[r:REQUIRE]->(m)
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Freelancer

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///freelancers_summary.csv' AS line
    MERGE (n:Freelancer {Id: line.FreelancerID})
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///freelancers_focus_area.csv' AS line
    MATCH (n:Freelancer) WHERE n.Id = line.FreelancerID
    MERGE (m:Area {Name: line.FocusAreaDescription})
    MERGE (n)-[r:FOCUS]->(m)
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///freelancers_certification.csv' AS line
    WITH line where line.CertificationValue IS NOT NULL
    MATCH (n:Freelancer) WHERE n.Id = line.FreelancerID
    MERGE (m:Certification {Name: line.CertificationValue})
    MERGE (n)-[r:HAS]->(m)
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Job & Freelancer

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///shortlist.csv' AS line
    MATCH (n:Freelancer) WHERE n.Id = line.FreelancerID
    MATCH (m:Job) WHERE m.Id = line.jobid
    MERGE (n)-[r:MATCH]->(m)
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
gds.run_cypher(
    '''
    LOAD CSV WITH HEADERS FROM 'file:///active_engagement.csv' AS line
    MATCH (n:Freelancer) WHERE n.Id = line.FreelancerID
    MATCH (m:Job) WHERE m.Id = line.jobid
    MERGE (n)-[r:MATCH]->(m)
    '''
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Search

# %%
pd.set_option('display.max_colwidth', None)
model = SentenceTransformer('C:/Users/xwang338/Desktop/Project/2022 - US - Talent Exchange NLP/Model')

# %% [markdown]
# ### Skill to Skill

# %%
name = '.NET'

cypher = '''
MATCH (n1:Skill)-[r1]-(n2)-[r2]-(n3:Skill)
WHERE n1.Name = '{}'
RETURN distinct(n3.Name) AS Result
'''.format(name)

df = gds.run_cypher(cypher)

sentences = df['Result'].values.tolist()
sentences.insert(0, name)

embeddings = model.encode(sentences)

similarity = cosine_similarity([embeddings[0]], embeddings[1:])
df['Similarity'] = similarity[0]
df.sort_values('Similarity', ascending = False)[1:11]
# Out:
#                Result  Similarity
# 4098          MS .NET    0.828114
# 768               NET    0.788151
# 3769         .NET 3.5    0.778005
# 2582         .NET 4.5    0.759161
# 1982         .NET 2.0    0.747829
# 4794         .NET 3.0    0.744971
# 314            C#.NET    0.741844
# 36            ASP.NET    0.711043
# 2116   .NET FRAMEWORK    0.685938
# 6259  NET DEVELOPMENT    0.669760

# %% [markdown]
# ### Skill to Certification

# %%
df = gds.run_cypher(
    '''
    MATCH (n1:Skill)-[r1]-(n2)-[r2]-(n3:Certification)
    WHERE n1.Name = 'MORTGAGE OPERATIONS'
    RETURN distinct(n3.Name) AS Result
    '''
)

sentences = df['Result'].values.tolist()
sentences.insert(0, 'MORTGAGE OPERATIONS')

embeddings = model.encode(sentences)

similarity = cosine_similarity([embeddings[0]], embeddings[1:])
df['Similarity'] = similarity[0]
df.sort_values('Similarity', ascending = False)[1:21]
# Out:
#                                                                                 Result  \
# 1                                      Licensed Realtor  Keller Williams (State of FL)
# 3                                               Licensed Insurance Adjuster  All Lines
# 6                                                                                  CPA
# 0                                              Certified Regulatory Compliance Manager
# 4                                                                       Public Notary
# 5                                                           Life and health insurance
# 7  Certified Public Accountant (CPA) Actively Licensed in the Commonwealth of Virginia
# 2         Florida Notary Public (Remote Online Notary  Certified Mobile Signing Agent)
#
#    Similarity
# 1    0.259704
# 3    0.210485
# 6    0.204352
# 0    0.184436
# 4    0.176066
# 5    0.147559
# 7    0.127877
# 2    0.118595

# %% [markdown]
# ### Certification to Skill

# %%
df = gds.run_cypher(
    '''
    MATCH (n1:Certification)-[r1]-(n2)-[r2]-(n3:Skill)
    WHERE n1.Name = 'Microsoft Certified Azure Fundamentals'
    RETURN distinct(n3.Name) AS Result
    '''
)

sentences = df['Result'].values.tolist()
sentences.insert(0, 'Microsoft Certified Azure Fundamentals')

embeddings = model.encode(sentences)

similarity = cosine_similarity([embeddings[0]], embeddings[1:])
df['Similarity'] = similarity[0]
df.sort_values('Similarity', ascending = False)[1:21]
# Out:
#                             Result  Similarity
# 126        MICROSOFT CLOUD - AZURE    0.682908
# 48                           AZURE    0.671717
# 186            MICROSOFT AZURE SQL    0.576094
# 59                       MICROSOFT    0.452627
# 98                   AWS CERTIFIED    0.451269
# 209                      .NET CORE    0.390944
# 72                  CLOUD SERVICES    0.384945
# 62                MICROSOFT OFFICE    0.374246
# 117         MICROSOFT OFFICE SUITE    0.372953
# 142  VIRTUALIZATION INFRASTRUCTURE    0.345281
# 129       MICROSOFT WINDOWS SERVER    0.344372
# 70               MICROSOFT WINDOWS    0.334478
# 154              Microsoft PowerBI    0.332692
# 228            DEVOPS TECHNOLOGIES    0.326042
# 201                  VISUAL STUDIO    0.317331
# 103         DATA CENTER OPERATIONS    0.316444
# 198                           .NET    0.311343
# 0         MICROSOFT PROJECT SERVER    0.308742
# 223                   WEB SERVICES    0.303005
# 80            MICROSOFT SQL SERVER    0.299336

# %% [markdown]
# ### Certification to Certification

# %%
df = gds.run_cypher(
    '''
    MATCH (n1:Certification)-[r1]-(n2)-[r2]-(n3:Certification)
    WHERE n1.Name = 'Microsoft Certified Azure Fundamentals'
    RETURN distinct(n3.Name) AS Result
    '''
)

sentences = df['Result'].values.tolist()
sentences.insert(0, 'Microsoft Certified Azure Fundamentals')

embeddings = model.encode(sentences)

similarity = cosine_similarity([embeddings[0]], embeddings[1:])
df['Similarity'] = similarity[0]
df.sort_values('Similarity', ascending = False)[1:21]
# Out:
#                                                                                          Result  \
# 0                                                     Microsoft Certified Azure AI Fundamentals
# 41                                         Microsoft Certified Azure Solutions Architect Expert
# 39                                            Microsoft Certified Azure Administrator Associate
# 16                                                                          Microsoft Certified
# 26                                        Microsoft Certified Azure Security Engineer Associate
# 42                                                                      Microsoft Cloud (Azure)
# 97                                                             Microsoft Certified Professional
# 74                                                                    Azure Databrick Certified
# 35                                                   Microsoft Certified DevOps Engineer Expert
# 103      Microsoft Certified Technology Specialist ( MCTS ) .Net Framework 2.0 Web Applications
# 69                                                             AWS Cloud Practitioner Certified
# 101                                      AWS (Amazon Web Services) Certified Cloud Practitioner
# 58                                                             AWS Certified Cloud Practitioner
# 98   Microsoft Certified Technology Specialist ( MCTS ) .NET Framework 3.5 ASP.NET Applications
# 81                                          AWS Certified Cloud Practitioner (Apr 2021Apr 2024)
# 105                                          Microsoft Certified Application Developer ( MCAD )
# 23                                                                       Google Cloud Certified
# 100                                         Microsoft Certified Professional Developer ( MCPD )
# 33                                                  Google Cloud Certified Digital Cloud Leader
# 2                                                          Certified SAFe 5 DevOps Practitioner
#
#      Similarity
# 0      0.809052
# 41     0.763384
# 39     0.729151
# 16     0.708583
# 26     0.704610
# 42     0.685291
# 97     0.678548
# 74     0.625291
# 35     0.598412
# 103    0.553795
# 69     0.547883
# 101    0.547619
# 58     0.526343
# 98     0.523953
# 81     0.511514
# 105    0.508411
# 23     0.507813
# 100    0.504150
# 33     0.471296
# 2      0.452771

# %% [markdown]
# ### Area to Skill

# %%
df = gds.run_cypher(
    '''
    MATCH (n1:Area)-[r1]-(n2)-[r2]-(n3:Skill)
    WHERE n1.Name = 'Finance Operations'
    RETURN distinct(n3.Name) AS Result
    '''
)

sentences = df['Result'].values.tolist()
sentences.insert(0, 'Finance Operations')

embeddings = model.encode(sentences)

similarity = cosine_similarity([embeddings[0]], embeddings[1:])
df['Similarity'] = similarity[0]
df.sort_values('Similarity', ascending = False)[1:21]
# Out:
#                                          Result  Similarity
# 1397                       FINANCIAL OPERATIONS    0.939034
# 837                          OPERATIONS FINANCE    0.917218
# 8033            FINANCE / ACCOUNTING OPERATIONS    0.874775
# 8402                 OTHER FINANCIAL OPERATIONS    0.860975
# 9207            ACCOUNTING & FINANCE OPERATIONS    0.857165
# 5490                         FINANCE MANAGEMENT    0.815904
# 450                                     Finance    0.801314
# 419                                     FINANCE    0.801314
# 12012                       OPERATIONAL FINANCE    0.797847
# 14834                  SALES OPERATIONS FINANCE    0.793662
# 15473  OPERATIONS & FINANCIAL BUSINESS ANALYSIS    0.783992
# 4614                         BANKING OPERATIONS    0.783966
# 7190                            BANK OPERATIONS    0.783887
# 1062                      ACCOUNTING OPERATIONS    0.762115
# 10386                           LOAN OPERATIONS    0.758362
# 1289                       FINANCIAL MANAGEMENT    0.757116
# 12772                      FINANCE / ACCOUNTING    0.756521
# 848                           CORPORATE FINANCE    0.753210
# 17195                         FINANCE PROCESSES    0.753075
# 6429                      INVESTMENT OPERATIONS    0.750070

# %% [markdown]
# ### Area to Certification

# %%
df = gds.run_cypher(
    '''
    MATCH (n1:Area)-[r1]-(n2)-[r2]-(n3:Certification)
    WHERE n1.Name = 'Finance Operations'
    RETURN distinct(n3.Name) AS Result
    '''
)

sentences = df['Result'].values.tolist()
sentences.insert(0, 'Finance Operations')

embeddings = model.encode(sentences)

similarity = cosine_similarity([embeddings[0]], embeddings[1:])
df['Similarity'] = similarity[0]
df.sort_values('Similarity', ascending = False)[1:21]
# Out:
#                                                                                                         Result  \
# 1246                                                                                     Finance and Insurance
# 1587                                                                          Securities Operations Overview I
# 6620                                                                              Corporate Finance Accounting
# 4988  Business of Shipping                                                                Financial Management
# 546                                                                                   Finance Training Society
# 7282                                                                             Emerging Issues in Operations
# 2490                                                                                      Finance Risk Manager
# 3786                                                                             Financial services specialist
# 666                                                                    Financial Industry Regulatory Authority
# 1245                                                                                                Accounting
# 4715                                                                                          Cash Management
# 1811                             Certified Financial Specialist (American Academy of Financial Management 2003
# 239                                                                                     Financial Risk Manager
# 7077                                                           Introduction to Finance (University of Michigan
# 5739                                                              Series 27 Financial and Operations Principal
# 7137                                                                         Banking and Financial Services L0
# 1231                                                                               Certified Financial Manager
# 4234                                                                                Math for corporate finance
# 3038                                                                    Accounting and Finance Accounting Core
# 135                                                                                Chartered Financial Analyst
#
#       Similarity
# 1246    0.663499
# 1587    0.662800
# 6620    0.656432
# 4988    0.638856
# 546     0.619971
# 7282    0.618675
# 2490    0.616463
# 3786    0.616402
# 666     0.611522
# 1245    0.607816
# 4715    0.598487
# 1811    0.597025
# 239     0.594243
# 7077    0.588736
# 5739    0.587166
# 7137    0.580655
# 1231    0.577962
# 4234    0.577748
# 3038    0.577717
# 135     0.573506

# %% [markdown]
# ### Skill to Area

# %%
df = gds.run_cypher(
    '''
    MATCH (n1:Skill)-[r1]-(n2)-[r2]-(n3:Area)
    WHERE n1.Name = 'ACCESS CONTROL'
    RETURN distinct(n3.Name) AS Result
    '''
)

sentences = df['Result'].values.tolist()
sentences.insert(0, 'ACCESS CONTROL')

embeddings = model.encode(sentences)

similarity = cosine_similarity([embeddings[0]], embeddings[1:])
df['Similarity'] = similarity[0]
df.sort_values('Similarity', ascending = False)[1:21]
# Out:
#                                             Result  Similarity
# 0                                Change Management    0.369716
# 9                                       Operations    0.349080
# 17                                           Audit    0.308890
# 3                           Application Technology    0.306323
# 20                              Finance Operations    0.298261
# 10                                 User Experience    0.279011
# 7                                              SAP    0.273189
# 19                  Cloud Computing and Networking    0.269428
# 18                              Data and Analytics    0.266607
# 2               Cybersecurity, Privacy & Forensics    0.258913
# 5                                           Oracle    0.251460
# 11                Program and Portfolio Management    0.235907
# 22                                  Tax Compliance    0.233016
# 6              Information Management and Big Data    0.216493
# 8                                         Strategy    0.206264
# 23                                       Guidewire    0.204358
# 16            Financial Services Risk & Regulatory    0.203747
# 1                              Risk and Regulatory    0.189745
# 12                                        Customer    0.181977
# 21  Health Industries Advisory Risk and Regulatory    0.146842

# %%
data = pd.read_excel('C:/Users/xwang338/Desktop/Project/2022 - US - Talent Exchange NLP/Data/New Microsoft Excel Worksheet.xlsx')
skill_list = data['Skill_Name'].tolist()

# %%
fnl_dic = {}

for name in skill_list:

    try:
        cypher = '''
        MATCH (n1:Skill)-[r1]-(n2)-[r2]-(n3:Skill)
        WHERE n1.Name = '{}'
        RETURN distinct(n3.Name) AS Result
        '''.format(name)

        df = gds.run_cypher(cypher)

        sentences = df['Result'].values.tolist()
        sentences.insert(0, name)

        embeddings = model.encode(sentences)

        similarity = cosine_similarity([embeddings[0]], embeddings[1:])
        df['Similarity'] = similarity[0]
        df = df.sort_values('Similarity', ascending = False)

        fnl_dic[name] = df['Result'][1:11].tolist()
    
    except:
        pass

# %%
fnl_dic
# Out:
# {'.NET': ['MS .NET',
#   'NET',
#   '.NET 3.5',
#   '.NET 4.5',
#   '.NET 2.0',
#   '.NET 3.0',
#   'C#.NET',
#   'ASP.NET',
#   '.NET FRAMEWORK',
#   'NET DEVELOPMENT'],
#  'ABAP FOR HANA': ['ABAP',
#   'SAP HANA',
#   'ABAP  SD',
#   'S/4 HANA',
#   'SAP HANA DB',
#   'ABAP/4',
#   'HANA CLOUD PLATFORM',
#   'SAP HANA STUDIO',
#   'BI S4/HANA',
#   'ABAP DEVELOPER'],
#  'ABINITIO': ['Ab Initio',
#   'ALGO',
#   'IAAS',
#   'TRANSLATE',
#   'BO',
#   'TRANSLATED',
#   'RELTIO',
#   'OBIEE/OBIA',
#   'TIBCO',
#   'ABAP'],
#  'ADF': ['ACTIVE DIRECTORY',
#   'FRAMEWORK',
#   'MICROSOFT ACTIVE DIRECTORY',
#   'MFA',
#   'DIGITAL ADVERTISING',
#   'EXCHANGE',
#   'EXCHANGE 2000',
#   'SALESFORCE',
#   'ASP',
#   'FA'],
#  'Adobe AEP': ['ADOBE CREATIVE CLOUD',
#   'ADOBE DOCUMENT CLOUD',
#   'ADOBE ILLUSTRATOR',
#   'AGILE, SCRUM (CSP, CSPO)',
#   'MICROSOFT 365',
#   'FINANCIAL RISK MANAGEMENT',
#   'INTERNET OF THINGS',
#   'PROGRAM MANAGEMENT',
#   'APPLICATION ARCHITECTURE',
#   'CLOUD SECURITY']}

# %%
fnl_df = pd.DataFrame.from_dict(fnl_dic, orient='index')

# %%
fnl_df
# Out:
#                                                                0  \
# .NET                                                     MS .NET
# ABAP FOR HANA                                               ABAP
# ABINITIO                                               Ab Initio
# ADF                                             ACTIVE DIRECTORY
# Adobe AEP                                   ADOBE CREATIVE CLOUD
# ...                                                          ...
# WEBCENTER                                             WEB PORTAL
# WEBLOGIC                                         WEBLOGIC SERVER
# WHITE COLLAR CRIME INVESTIGATIONS  WHITE COLLAR, CORPORATE CRIME
# WORK CLEARANCE MANAGEMENT               WORK CONTROL SUPERVISION
# WORKFORCE PLANNING                            Workforce Modeling
#
#                                                                                    1  \
# .NET                                                                             NET
# ABAP FOR HANA                                                               SAP HANA
# ABINITIO                                                                        ALGO
# ADF                                                                        FRAMEWORK
# Adobe AEP                                                       ADOBE DOCUMENT CLOUD
# ...                                                                              ...
# WEBCENTER                                                       ORACLE ADF WEBCENTER
# WEBLOGIC                                                             WEBLOGIC PORTAL
# WHITE COLLAR CRIME INVESTIGATIONS                            CRIMINAL INVESTIGATIONS
# WORK CLEARANCE MANAGEMENT                                     MAXIMO WORK MANAGEMENT
# WORKFORCE PLANNING                 WORKFORCE CAPABILITY - STRATEGIC WORKFORCE PLANNI
#
#                                                               2  \
# .NET                                                   .NET 3.5
# ABAP FOR HANA                                          ABAP  SD
# ABINITIO                                                   IAAS
# ADF                                  MICROSOFT ACTIVE DIRECTORY
# Adobe AEP                                     ADOBE ILLUSTRATOR
# ...                                                         ...
# WEBCENTER                                             WEBTRENDS
# WEBLOGIC                                        ORACLE WEBLOGIC
# WHITE COLLAR CRIME INVESTIGATIONS          CIVIL INVESTIGATIONS
# WORK CLEARANCE MANAGEMENT                               PAYROLL
# WORKFORCE PLANNING                 ANALYTICS WORKFORCE PLANNING
#
#                                                                          3  \
# .NET                                                              .NET 4.5
# ABAP FOR HANA                                                     S/4 HANA
# ABINITIO                                                         TRANSLATE
# ADF                                                                    MFA
# Adobe AEP                                         AGILE, SCRUM (CSP, CSPO)
# ...                                                                    ...
# WEBCENTER                                                CUSTOMER DATA HUB
# WEBLOGIC                                                       WEBLOGIC WS
# WHITE COLLAR CRIME INVESTIGATIONS                GOVERNMENT INVESTIGATIONS
# WORK CLEARANCE MANAGEMENT          ADMIN PERSONNEL RELATED TOMANUFACTURING
# WORKFORCE PLANNING                 WORKFORCE MANAGEMENT - LABOR SCHEDULING
#
#                                                                             4  \
# .NET                                                                 .NET 2.0
# ABAP FOR HANA                                                     SAP HANA DB
# ABINITIO                                                                   BO
# ADF                                                       DIGITAL ADVERTISING
# Adobe AEP                                                       MICROSOFT 365
# ...                                                                       ...
# WEBCENTER                                           ORACLE WEB CENTER IMAGING
# WEBLOGIC                                                     WEBLOGIC SERVERS
# WHITE COLLAR CRIME INVESTIGATIONS                      PRIVATE INVESTIGATIONS
# WORK CLEARANCE MANAGEMENT                                          MANAGEMENT
# WORKFORCE PLANNING                 WORKFORCE CAPABILITY - SUCCESSION PLANNING
#
#                                                            5  \
# .NET                                                .NET 3.0
# ABAP FOR HANA                                         ABAP/4
# ABINITIO                                          TRANSLATED
# ADF                                                 EXCHANGE
# Adobe AEP                          FINANCIAL RISK MANAGEMENT
# ...                                                      ...
# WEBCENTER                                           NETSUITE
# WEBLOGIC                                   WEBSHERE/WEBLOGIC
# WHITE COLLAR CRIME INVESTIGATIONS             INVESTIGATIONS
# WORK CLEARANCE MANAGEMENT           HUMAN CAPITAL MANAGEMENT
# WORKFORCE PLANNING                   WORKFORCE RESTRUCTURING
#
#                                                        6  \
# .NET                                              C#.NET
# ABAP FOR HANA                        HANA CLOUD PLATFORM
# ABINITIO                                          RELTIO
# ADF                                        EXCHANGE 2000
# Adobe AEP                             INTERNET OF THINGS
# ...                                                  ...
# WEBCENTER                                MARKETING CLOUD
# WEBLOGIC                              WEBLOGIC WORKBENCH
# WHITE COLLAR CRIME INVESTIGATIONS         Investigations
# WORK CLEARANCE MANAGEMENT                             HR
# WORKFORCE PLANNING                 ANALYTICS - WORKFORCE
#
#                                                                                  7  \
# .NET                                                                       ASP.NET
# ABAP FOR HANA                                                      SAP HANA STUDIO
# ABINITIO                                                                OBIEE/OBIA
# ADF                                                                     SALESFORCE
# Adobe AEP                                                       PROGRAM MANAGEMENT
# ...                                                                            ...
# WEBCENTER                                                               SHAREPOINT
# WEBLOGIC                                                              BEA WEBLOGIC
# WHITE COLLAR CRIME INVESTIGATIONS                         FINANCIAL INVESTIGATIONS
# WORK CLEARANCE MANAGEMENT                                       WORK CO-ORDINATION
# WORKFORCE PLANNING                 WORKFORCE CAPABILITY - SOURCING AND RECRUITMENT
#
#                                                                  8  \
# .NET                                                .NET FRAMEWORK
# ABAP FOR HANA                                           BI S4/HANA
# ABINITIO                                                     TIBCO
# ADF                                                            ASP
# Adobe AEP                                 APPLICATION ARCHITECTURE
# ...                                                            ...
# WEBCENTER                                    IBM WEB SPHERE PORTAL
# WEBLOGIC                                       WEBLOGIC APP SERVER
# WHITE COLLAR CRIME INVESTIGATIONS                            CRIME
# WORK CLEARANCE MANAGEMENT                     ADMINISTRATIVE TASKS
# WORKFORCE PLANNING                 CAREER DEVELOPMENT AND PLANNING
#
#                                                                     9
# .NET                                                  NET DEVELOPMENT
# ABAP FOR HANA                                          ABAP DEVELOPER
# ABINITIO                                                         ABAP
# ADF                                                                FA
# Adobe AEP                                              CLOUD SECURITY
# ...                                                               ...
# WEBCENTER                                                        HTTP
# WEBLOGIC                                       Oracle WebLogic Server
# WHITE COLLAR CRIME INVESTIGATIONS                FRAUD INVESTIGATIONS
# WORK CLEARANCE MANAGEMENT                                    WORKFLOW
# WORKFORCE PLANNING                 DATA TRACKING / WORKFORCE ANALYSIS
#
# [345 rows x 10 columns]

# %%
fnl_df.to_csv('C:/Users/xwang338/Desktop/Project/2022 - US - Talent Exchange NLP/Data/result.csv')
