# %%
# imports
import spacy
from spacy.matcher import PhraseMatcher

# load default skills data base
from skillNer.general_params import SKILL_DB
# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor
# Out:
# C:\Users\xwang338\.conda\envs\Python_3.10\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# init params of skill extractor
nlp = spacy.load("en_core_web_lg")

# %%
# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)

# extract skills from job_description
job_description = """
You are a Python developer with a solid experience in web development
and can manage projects. You quickly adapt to new environments
and speak fluently English and French
"""

annotations = skill_extractor.annotate(job_description)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %%
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspyou are a&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_263()'onmouseenter='mouseEnterHandler_KS125LS6N7WP4S6SFTCK_263()'>
#             python
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS125LS6N7WP4S6SFTCK_263'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
# ...

# %%
job_description = """
Professional in the Financial Services Industry with extensive experience with a Fortune 500 organization focusing on risk management, compliance, USA PATRIOT ACT, Bank Secrecy Act, politically exposed persons, terrorist financing, KYC, KYC Remediation, due diligence, internal and external customer relationships, and process improvements. 
Expertise includes: Compliance, Financial Investigations, Training, Risk Management, Correspondent Banking and Transaction Monitoring experience. 
Proficient in MS Office Products and able to skillfully use a variety of research software.
"""

annotations = skill_extractor.annotate(job_description)
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#
#         <span class='relative p-1 text-white rounded-md border bg-blue-500' onmouseleave='mouseLeaveHandler_ES76F4C57A88877D6D64_86()'onmouseenter='mouseEnterHandler_ES76F4C57A88877D6D64_86()'>
#             professional
#         <span class='text-xs text-white font-bold' >
#              ( Soft Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='ES76F4C57A88877D6D64_86'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
# ...

# %%
job_description = """
Data privacy and GDPR leader and SME with track record of success in leading global and enterprise initiatives.  
Healthcare, financial, entertainment, and cloud experience in-depth.  
Virtual CISO to Fortune 100 and top consulting organizations.  
Engage with board, C-level, management, staff, and regulatory agencies on GDPR, CCPA, data privacy requirements and privacy-by-design.  
Achieve CIA triad through strategic prioritization, planning, project and program management, vendor risk management, hands-on leadership of project teams, and flawless execution.  
Deliver effective, executable gap assessments, remediation programs, cybersecurity risk management systems, vendor risk assessment programs, policies, and procedures that ensure ongoing standards compliance.  
Design, implement and manage detailed incident management procedures, organization-wide information security awareness, and training.
"""

annotations = skill_extractor.annotate(job_description)
skill_extractor.describe(annotations)
# Out:
# C:\Users\xwang338\.conda\envs\Python_3.10\lib\site-packages\skillNer\utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspdata privacy and gdpr leader and sme with&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS441GF6KQ6M65WY8DJ3_898()'onmouseenter='mouseEnterHandler_KS441GF6KQ6M65WY8DJ3_898()'>
#             track
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
# ...

# %%
job_description = """
My career objective is to obtain a challenging position in Regulatory Compliance Audit/Analysis, 
where my knowledge of Mortgage Lending, Consumer Lending Laws, Anti-Money Laundering Regulations, Real Estate Finance, and Risk Management skills can be fully utilized. 
A value add to any team or organization.
"""

annotations = skill_extractor.annotate(job_description)
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspmy career objective is to obtain a challenging&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-blue-500' onmouseleave='mouseLeaveHandler_ESB7D4D9034BC8B2CAB1_374()'onmouseenter='mouseEnterHandler_ESB7D4D9034BC8B2CAB1_374()'>
#             position
#         <span class='text-xs text-white font-bold' >
#              ( Soft Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='ESB7D4D9034BC8B2CAB1_374'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
# ...

# %%
for i in range(0, len(annotations['results']['full_matches'])):
    print(annotations['results']['full_matches'][i]['doc_node_value'])
# Out:
# regulatory compliance
# consumer lending
# anti money laundering
# real estate
# real estate finance
# risk management

# %%
for i in range(0, len(annotations['results']['ngram_scored'])):
    print(annotations['results']['ngram_scored'][i]['doc_node_value'])
# Out:
# position
# audit
# lending consumer
# value add

# %%
def get_skill(line):
    
    dic = {}
    ls = []
    
    if not pd.isnull(line['Summary']):

        key = line['FreelancerID']

        try:
            annotations = skill_extractor.annotate(line['Summary'])
            
            for i in range(0, len(annotations['results']['full_matches'])):
                ls.append(annotations['results']['full_matches'][i]['doc_node_value'])

            for i in range(0, len(annotations['results']['ngram_scored'])):
                ls.append(annotations['results']['ngram_scored'][i]['doc_node_value'])

            dic[line['FreelancerID']] = ls
        
        except Exception:
            print(line['FreelancerID'])
            
    return(dic)

pd.DataFrame(get_skill(df.iloc[95]).items(), columns=['FreelancerID', 'SkillName']).explode('SkillName')
# Out:
# 107
# Empty DataFrame
# Columns: [FreelancerID, SkillName]
# Index: []

# %%
import pandas as pd

folder = 'C:/Users/xwang338/Desktop/Project/2022 - US - Talent Exchange NLP/Data/'
file = 'freelancers.xlsx'


skill_dic = get_skill(job_description)

skill_dic

df = pd.read_excel(folder + file, sheet_name = 'freelancer summary')

# %%
skill = df.apply(lambda row : get_skill(row), axis = 1)
# Out:
# C:\Users\xwang338\.conda\envs\Python_3.10\lib\site-packages\skillNer\utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)
# C:\Users\xwang338\.conda\envs\Python_3.10\lib\site-packages\skillNer\utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)
# C:\Users\xwang338\.conda\envs\Python_3.10\lib\site-packages\skillNer\utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)
# C:\Users\xwang338\.conda\envs\Python_3.10\lib\site-packages\skillNer\utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)
# C:\Users\xwang338\.conda\envs\Python_3.10\lib\site-packages\skillNer\utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
# ...

# %%
job_description = """
For over 15 years, Amanda has been developing customized solutions to complex business problems for a variety of Fortune 500 companies.
She has a proven ability to lead and manage an effective team, and she excels at working closely with business owners to develop solutions that meet their needs. 
Her primary area of expertise is working with the Hyperion Enterprise Performance Management System. 
She has worked with Essbase since version 4.12 and is an expert at creating and optimizing Hyperion applications, databases, and complex calculations.
These proficiencies, coupled with her excellent communication skills, make her a valuable addition to any project.
Specialties: Hyperion Essbase, Hyperion Planning, Hyperion Reports, Calculation Manager, Requirements Gathering, Software Design, Documentation, Hyperion Essbase Certified
"""

annotations = skill_extractor.annotate(job_description)
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspfor over 15 years amanda has been&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_ES2293CD01E12A395E9F_119()'onmouseenter='mouseEnterHandler_ES2293CD01E12A395E9F_119()'>
#             developing customized
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='ES2293CD01E12A395E9F_119'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
# ...

# %%
skill
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [89], in <cell line: 1>()
# ----> 1 skill
#
# NameError: name 'skill' is not defined
